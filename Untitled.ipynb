# %% [markdown]
# #Creating Synthetic data set for the project

# %%
import random
import pandas as pd

# %%
first_names = ["Aarav", "Vihaan", "Aditya", "Ishaan", "Kabir", "Rohan", "Aryan", "Saanvi", "Ananya", "Diya"]
last_names = ["Mehta", "Sharma", "Verma", "Patel", "Iyer", "Nair", "Gupta", "Singh", "Reddy", "Joshi"]

# %%
def generate_record():

    name = f"{random.choice(first_names)} {random.choice(last_names)}"

    dob = f"{random.randint(1,28):02d}/{random.randint(1,12):02d}/{random.randint(1980,2002)}"

    pan = "".join(random.choices("ABCDEFGHIJKLMNOPQRSTUVWXYZ", k=5)) + \
          str(random.randint(1000,9999)) + \
          random.choice("ABCDEFGHIJKLMNOPQRSTUVWXYZ")

    ocr_text = f"""Name: {name}
DOB: {dob}
PAN: {pan}"""

    transactions = []
    for _ in range(random.randint(2,5)):
        ttype = random.choice(["credit", "debit"])
        mode = random.choice(["salary", "upi", "cash", "card"])
        amount = random.randint(1000, 100000)

        transactions.append({
            "amount": amount,
            "type": ttype,
            "mode": mode
        })

    pep_flag = random.choice([0,0,0,1])        # rare risk
    sanctions_flag = random.choice([0,0,0,0,1])

    return {
        "ocr_text": ocr_text,
        "name": name,
        "matched_name": name,
        "transactions": transactions,
        "pep_flag": pep_flag,
        "sanctions_flag": sanctions_flag
    }

# %%
dataset = [generate_record() for _ in range(100)]

print(dataset[0])
# Out:
# {'ocr_text': 'Name: Vihaan Verma\nDOB: 08/07/1985\nPAN: RRFPY7902M', 'name': 'Vihaan Verma', 'matched_name': 'Vihaan Verma', 'transactions': [{'amount': 84254, 'type': 'credit', 'mode': 'cash'}, {'amount': 27664, 'type': 'debit', 'mode': 'card'}, {'amount': 25472, 'type': 'credit', 'mode': 'upi'}, {'amount': 92923, 'type': 'credit', 'mode': 'cash'}], 'pep_flag': 0, 'sanctions_flag': 1}

# %%
df = pd.DataFrame(dataset)
df.head()
# Out:
#                                             ocr_text           name  \
# 0  Name: Vihaan Verma\nDOB: 08/07/1985\nPAN: RRFP...   Vihaan Verma
# 1  Name: Ishaan Gupta\nDOB: 08/03/1996\nPAN: JHRB...   Ishaan Gupta
# 2  Name: Saanvi Reddy\nDOB: 04/10/2002\nPAN: BXVQ...   Saanvi Reddy
# 3  Name: Saanvi Joshi\nDOB: 12/05/1985\nPAN: QEPT...   Saanvi Joshi
# 4  Name: Vihaan Sharma\nDOB: 10/10/1995\nPAN: NFU...  Vihaan Sharma
#
#     matched_name                                       transactions  pep_flag  \
# 0   Vihaan Verma  [{'amount': 84254, 'type': 'credit', 'mode': '...         0
# 1   Ishaan Gupta  [{'amount': 14337, 'type': 'debit', 'mode': 'c...         1
# 2   Saanvi Reddy  [{'amount': 94875, 'type': 'credit', 'mode': '...         0
# 3   Saanvi Joshi  [{'amount': 92720, 'type': 'debit', 'mode': 'c...         1
# 4  Vihaan Sharma  [{'amount': 60123, 'type': 'debit', 'mode': 'c...         0
#
#    sanctions_flag
# 0               1
# 1               0
# 2               0
# 3               0
# 4               1

# %%
import pandas as pd

df = pd.DataFrame(dataset)

df.to_csv("kyc_synthetic_data.csv", index=False)
